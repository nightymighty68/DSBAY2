# %%
from numpy import sqrt


n = 141818
x=0
for i in range(2,n):
    if (n%i==0):
        x=x+1

if(x==0):
    print(f"{n} is a prime  number")
else:
    print(f"{n} is not a prime number")
# Out:
# 141818 is not a prime number
