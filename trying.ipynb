# %%
import numpy as np

string ="*"
x=6


for i in range(5):
    x=x-1
    print(" "*(5-x) + string * x)

y=6
for i in range(5):
    y=y-1
    print( string * y)
# Out:
# *****
#  ****
#   ***
#    **
#     *
# *****
# ****
# ***
# **
# *

# %%
string = "*"
rows = 5        # number of lines
length = 9    # length of the first row

for i in range(rows):
    print(" " * i + string * (length - i*2))
# Out:
# *********
#  *******
#   *****
#    ***
#     *
